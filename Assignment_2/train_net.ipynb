# %%
import pandas;
import numpy as np;
import os.path;
import os;
# %matplotlib inline
np.set_printoptions(suppress=True)

# %%
def readCSVFile(file):
    data=pandas.read_csv(file,",",header=0, na_values='?', skipinitialspace=True);
    return data;
    pass;
def readTrainData(dataset):    
    return dataset.ix[:,1:-1], dataset.ix[:,-1:];
    pass;

def readTestData(dataset):    
    return dataset.ix[:,1:],dataset.ix[:,0:1];
    pass;

def normalizePhi(unNormalizedPhi,last_col_bias=False):    
    #assuming last column as bias column
    no_of_column=len(unNormalizedPhi[0]);
    phi=np.array(unNormalizedPhi);
    print("Normalizing Phi...");  
    std=phi.std(0);
    mean=phi.mean(0);    
    std[no_of_column-1]=1;
    mean[no_of_column-1]=0;
    #phi_normalize=(phi-mean)/std;    
    
    max_vector=phi.max(axis=0)
    phi_normalize=phi/max_vector;    
    
    print("Normalization done.");
    return phi_normalize;
    pass;

def writeTestData(test_id,ystar,filenumber=0,filename=None):
    if(filename==None):
        fo = open("log/output/sampleSubmission-"+str(filenumber)+".csv", "w");               
    else:
        fo = open(filename+".csv", "w");        
    fo.write("id,salary\n");
    m=len(ystar);
    for i in range(m):
        fo.write(str(test_id[i][0])+","+str(ystar[i][0])+"\n");
    fo.close();
    pass;

def dropColumns(dataframe,colList):
    for c in colList:
        dataframe.drop([c], axis = 1, inplace = True);
    pass;

def addColByCategory(dataset):
    return pandas.get_dummies(dataset);
    pass;

def categoryToNumber(dataset,categoryList):
    for c in categoryList:
        if (c in dataset):            
            dataset[c]=pandas.get_dummies(dataset[c]).values.argmax(1);        
    return dataset;
    pass;
    

def handleCategoryData(dataset,categoryList=None,byNumber=False):
    if(byNumber):
        return categoryToNumber(dataset,categoryList)
    else:
        return addColByCategory(dataset);
    
def findMostFrequentCount(dataset):
    #arr=dataset;
    #axis = 0
    #u, indices = np.unique(arr, return_inverse=True)
    #print(u);
    #u[np.argmax(np.apply_along_axis(np.bincount, axis, indices.reshape(arr.shape),None, np.max(indices) + 1), axis=axis)]
    x = np.array([0, 1, 1, 3, 2, 1, 2, 3]);
    w=np.bincount(dataset[:,1].astype(int))#work-class: Private
    o=np.bincount(dataset[:,6].astype(int))#occupation: Married-civ-spouse
    c=np.bincount(dataset[:,13].astype(int))#country : US
    pass;

def fillNanValue(dataframe,col,value):
    if (col in dataframe):
        dataframe[col].fillna(value, inplace=True);
    pass;

def imputeUnknowValue(dataframe):
    #by most frequent value;
    fillNanValue(dataframe,"workclass","Private");
    fillNanValue(dataframe,"occupation","Craft-repair");
    fillNanValue(dataframe,"native-country","United-States");
    pass;

def addRemainingCol(colList,dataframe,rowCount):
    i=0;
    for c in colList:
        if( c not in dataframe):
            dataframe.insert(i, c, 0);
        i+=1;
    pass;

# %%
class NN:
    logging_enabled=True;
    trained_ds=None;
    trained_output=None;
    no_of_hiddenlayer=0;
    neurons_per_hiddenlayer=0;    
    weights=list();#list of matrix of weights
    layer_output=list();#vector of layers
    layer_delta=list(); 
    layer_error=list(); 
    no_of_iteration=1;
    mean_print_rate=10000;
    percent_print_rate=1000;
    learning_rate=1;
    approching_to_zero=1e-15;
    approching_to_one=1-1e-15;
    lamda=0.001;
    log_dir="log";
    log_folder=None;
    enable_bias_per_hidden=False;
    def __init__(self):
        np.random.seed(1);
        self.log_folder=self.log_dir+"/"+self.getTimestamp();
        self.createDir(self.log_folder);
        pass;
    
    def reInit(self):        
        self.layer_output=[0]*(self.no_of_hiddenlayer+2);
        self.layer_delta=[0]*(self.no_of_hiddenlayer+2);
        self.layer_error=[0]*(self.no_of_hiddenlayer+2);        
        pass;
        
    def createNN(self):
        self.no_of_features=len(self.trained_ds[0]);
        self.no_of_datapoint=len(self.trained_ds); 
        if(self.enable_bias_per_hidden and self.neurons_per_hiddenlayer>1):
            self.neurons_per_hiddenlayer+=1;#adding bias neuron whose o/p will always be 1;
            
        self.reInit();
        self.initWeightMatrix();       
        print("Neural Network Created...");
        pass;
    
    def initWeightMatrix(self):
        self.weights=list();
        for i in range(self.no_of_hiddenlayer):
            if(i==0):
                m=self.no_of_features;
            else:
                m=self.neurons_per_hiddenlayer;
            w_matrix = 2*np.random.random((m,self.neurons_per_hiddenlayer)) - 1;            
            
            if(self.enable_bias_per_hidden):
                #making weights of bias neuron as zero. So that its o/p is always one.
                w_matrix[:,0]=0;
                
            self.weights.append(w_matrix);
            #print(w_matrix);
            
        #last layer weight: For single output
        if(self.no_of_hiddenlayer==0):
            n=self.no_of_features;
        else:
            n=self.neurons_per_hiddenlayer;
        w_vector=2*np.random.random((n,1)) - 1;
        #print(w_vector);
        self.weights.append(w_vector);
        self.weights=np.array(self.weights);
        pass;
        
    def getTimestamp(self):
        import os.path;
        import datetime;
        import time;
        ts = datetime.datetime.fromtimestamp(time.time()).strftime('%d-%m-%Y-%H:%M:%S')
        return ts;

    def createDir(self,directory):
        import os.path;
        if not os.path.exists(directory):
            os.makedirs(directory);
        pass;
    
    def writeWeights(self,filenumber=0):
        fname=self.log_folder+"/weights-"+str(filenumber)+"-";
        m=len(self.weights);
        for i in range(m):
            np.save(fname+""+str(i), nn.weights[i])        
        pass;
    
    def writeWeights(self,filenumber=0):
        fname=self.log_folder+"/weights-"+str(filenumber)+"-";
        m=len(self.weights);
        for i in range(m):
            np.save(fname+""+str(i), self.weights[i])        
        pass;
    import os;


    def writeFinalWeights(self):
        filename="weights";        
        np.save(filename, self.weights);
        os.rename(filename+".npy", filename+".txt");
        pass;

    
    def loadWeights(self,folder=None,filename_offset="weights-0-",filename=None):        
        w=list();
        i=0;
        if(filename==None):
            file_path=folder+"/"+filename_offset+str(i)+".npy";        
            while (os.path.isfile(file_path)):
                w.append(np.load(file_path));
                i+=1;
                file_path=folder+"/"+filename_offset+str(i)+".npy";
            self.weights=w;
        else:
            self.weights=np.load(filename);
        return w;
    pass

    def activationFunction(self,x,deriv=False):
        return self.actFunSigmoid(x,deriv);
    
    def actFunSigmoid(self,x,deriv=False):
        if(deriv==True):
            return x*(1-x)
        return 1/(1+np.exp(-x))
    
    def actFunReLu(self,x,deriv=False):
        p = x > 0;            
        if(deriv==True):
            return p.astype(int);
        return x * p;
    
    def forwardPropogation(self,datapoints):        
        #intial layer i.e l0 zeroth layer
        self.layer_output[0]=datapoints;
        for i in range(1,self.no_of_hiddenlayer+2):
            prev_layer=self.layer_output[i-1];
            w=self.weights[i-1]
            sum_l=prev_layer.dot(w);           
            l_i=self.activationFunction(sum_l);
            self.layer_output[i]=l_i;   
            if(self.enable_bias_per_hidden and i<=self.no_of_hiddenlayer):
                #making weights of bias neuron as zero. So that its o/p is always one.
                l_i[:,0]=1;
            #print("l"+str(i)+":",l_i);
        return self.layer_output[self.no_of_hiddenlayer+1];
        pass;
    
    def findError(self):
        self.backPropogation(sel.layer_output);
        return self.getMeanError();
        
    def backPropogation(self,l_output):
        last_layer=len(l_output)-1;            
        
        #(target-output)        
        li=l_output[last_layer];
        error_diff=self.trained_output-li;
        delta=error_diff*self.activationFunction(li,deriv=True)    
        self.layer_delta[last_layer]=delta;
        self.layer_error[last_layer]=error_diff;
        
        for i in range(last_layer-1,0,-1):            
            #i-1 th layer calculation of delta
            error_diff=self.layer_delta[i+1].dot(self.weights[i].T);
            #print("l"+str(i)+"_error:",delta);
            delta=error_diff*self.activationFunction(l_output[i],deriv=True)
            self.layer_delta[i]=delta;
            self.layer_error[i]=error_diff;  
            
        #print("l"+str(i)+"_delta:",delta);        
        pass;
    
    def updateWeights(self,l_delta):
        #print(self.learning_rate);
        for i in range(self.no_of_hiddenlayer,-1,-1): # loop upto 0
            #print(str(i)+"==>a",self.weights[i][0]);            
            #print(str(i)+"==>b",self.layer_output[i].T.dot(l_delta[i+1])[0])
            #print(str(i)+"==>c",(self.lamda*self.weights[i])[0])            
            self.weights[i]+=self.learning_rate*self.layer_output[i].T.dot(l_delta[i+1]);
            if(self.lamda!=0):
                self.weights[i]-=self.learning_rate*-((self.lamda)*self.weights[i]);
            #print("w"+str(i)+":",self.layer_output[i].T.dot(l_delta[i+1]));
    
    
    def getMeanError(self):   
        return np.mean(np.abs(self.layer_error[self.no_of_hiddenlayer+1]));
    
    def getTrainedStatus(self,predicted_y):
        index = ["Neural-Network"];
        columns = ["Mean","Misclassified", "Accuracy"];
        status = pandas.DataFrame(index=index, columns=columns);       
        t_y=self.getThresholdValue(predicted_y);
        error_diff=self.trained_output-predicted_y;
        mean=np.mean(np.abs(error_diff));
        misclassifed= (self.trained_output != t_y).sum();
        accuracy = (len(t_y) - misclassifed) / len(t_y);
        status.ix["Neural-Network"]=[mean,misclassifed,accuracy];
        return status;
    
    def gradientDescent(self):
        for i in range(self.no_of_iteration):
            result=self.forwardPropogation(self.trained_ds);
            self.backPropogation(self.layer_output);            
            
            if ((i%self.mean_print_rate==0 or i >=self.no_of_iteration-6)):
                self.log(str(i)+"Error:",self.getMeanError());
                self.log(self.getTrainedStatus(result));
                
            if (i%self.percent_print_rate==0 or i >=self.no_of_iteration-6):
                self.log(str(i)+"Percent completed",(i*100)/self.no_of_iteration)
                #self.writeWeights();        
            if(i!=self.no_of_iteration-1):#donot update for last iteration            
                self.updateWeights(self.layer_delta);
        print("Error:",self.getMeanError());
        self.writeWeights();
        pass;
    
    def getThresholdValue(self,result,threshold=0.5):
        return(result>threshold).astype(int);

    def train(self):
         self.gradientDescent();
            
    def predict(self,datapoints):#forward propogation
        loutput=[0]*(self.no_of_hiddenlayer+2);
        #intial layer i.e l0 zeroth layer
        loutput[0]=datapoints;
        for i in range(1,self.no_of_hiddenlayer+2):
            prev_layer=loutput[i-1];
            w=self.weights[i-1]
            sum_l=prev_layer.dot(w);           
            l_i=self.activationFunction(sum_l);
            loutput[i]=l_i;   
            if(self.enable_bias_per_hidden and i<=self.no_of_hiddenlayer):
                #making weights of bias neuron as zero. So that its o/p is always one.
                l_i[:,0]=1;
        return loutput[self.no_of_hiddenlayer+1];
        pass;
    
    def log(self,text,data=None):
        if self.logging_enabled:
            if(data!=None):
                print(text,data);
            else:
                print(text);
        pass;
pass;

# %%
#--settings--
pandas.set_option('display.max_columns', None);
#---init---
dir="data/"
trainFile=dir+"train.csv";
testFile=dir+"kaggle_test_data.csv";
categoryList=["workclass","education","marital-status","occupation","relationship","race","sex","native-country"];
drop_col=["native-country","race","education"]
trained_dataset=readCSVFile(trainFile);
trained_data,trained_y=readTrainData(trained_dataset);

test_dataset=readCSVFile(testFile);
test_data,test_id=readTestData(test_dataset);

#droping unrelated-columns
dropColumns(trained_data,drop_col);
dropColumns(test_data,drop_col);

#impute:
imputeUnknowValue(trained_data);
imputeUnknowValue(test_data);

#converting categorical data to point wise data
byNumber=False;
dummy_trained_data=handleCategoryData(trained_data,categoryList,byNumber);
dummy_test_data=handleCategoryData(test_data,categoryList,byNumber);


#adding missing column
trained_columns_name=list(dummy_trained_data.columns.values);
addRemainingCol(trained_columns_name,dummy_test_data,len(trained_data))
test_columns_name=list(dummy_test_data.columns.values);

#converting panda data frame to numpy martix
mtx_dummy_tds=dummy_trained_data.as_matrix(columns=None)
mtx_dummy_testds=dummy_test_data.as_matrix(columns=None)
mtx_trained_y=trained_y.as_matrix(columns=None);
mtx_test_id=test_id.as_matrix(columns=None);

#adding bias column
mtx_dummy_tds=np.column_stack((mtx_dummy_tds,np.ones((len(mtx_dummy_tds),1))))
mtx_dummy_testds=np.column_stack((mtx_dummy_testds,np.ones((len(mtx_dummy_testds),1))))

#normalization
mtx_dummy_tds_norm=normalizePhi(mtx_dummy_tds)
mtx_dummy_testds_norm=normalizePhi(mtx_dummy_testds)


#print(mtx_dummy_tds)
#print(mtx_dummy_tds_norm)
#pandas.get_dummies(trained_data.ix[:,1:2])
print("train",np.shape(mtx_dummy_tds_norm),"test",np.shape(mtx_dummy_testds_norm));
# Out:
# Normalizing Phi...
# Normalization done.
# Normalizing Phi...
# Normalization done.
# train (38973, 44) test (6878, 44)

# %%
#neural network
#dataset: census income
nn= NN();
x=mtx_dummy_tds_norm;
y=mtx_trained_y;
nn.no_of_hiddenlayer=2;
nn.neurons_per_hiddenlayer=20;
nn.no_of_iteration=1001;
nn.learning_rate=0.0001;
nn.lamda=0;
nn.mean_print_rate=20;
nn.percent_print_rate=20;
nn.enable_bias_per_hidden=True;

#Common setting
nn.logging_enabled=True;
nn.trained_ds=x;
nn.trained_output=y;
nn.createNN();
nn.initWeightMatrix();
#nn.loadWeights("log/09-04-2017-00:58:20");
nn.train();
nn.writeFinalWeights();
result=nn.predict(x);
print("predicted",result);
print("Predicted-Th",nn.getThresholdValue(result));
print("Actual",y);
result=nn.predict(mtx_dummy_testds_norm);
writeTestData(mtx_test_id,result,filenumber=nn.getMeanError());
#writeTestData(mtx_test_id,nn.getThresholdValue(result),filename="predictions");
# Out:
# Neural Network Created...
# 0Error: 0.54722054055
#                     Mean Misclassified  Accuracy
# Neural-Network  0.547221         28888  0.258769
# 0Percent completed 0.0
# 20Error: 0.34963211754
#                     Mean Misclassified  Accuracy
# Neural-Network  0.349632          9345  0.760219
# 20Percent completed 1.998001998001998
# 40Error: 0.326791489156
#                     Mean Misclassified  Accuracy
# Neural-Network  0.326791          8945  0.770482
# 40Percent completed 3.996003996003996
# 60Error: 0.308472872032
#                     Mean Misclassified  Accuracy
# Neural-Network  0.308473          8754  0.775383
# 60Percent completed 5.994005994005994
# 80Error: 0.296098843396
#                     Mean Misclassified  Accuracy
# Neural-Network  0.296099          8451  0.783158
# 80Percent completed 7.992007992007992
# 100Error: 0.287068546385
#                     Mean Misclassified  Accuracy
# Neural-Network  0.287069          7581  0.805481
# 100Percent completed 9.99000999000999
# 120Error: 0.279868800074
#                     Mean Misclassified  Accuracy
# Neural-Network  0.279869          7162  0.816232
# 120Percent completed 11.988011988011989
# 140Error: 0.273845890121
#                     Mean Misclassified  Accuracy
# Neural-Network  0.273846          7038  0.819413
# 140Percent completed 13.986013986013987
# 160Error: 0.268737464172
#                     Mean Misclassified  Accuracy
# Neural-Network  0.268737          7012  0.820081
# 160Percent completed 15.984015984015985
# 180Error: 0.264428051662
#                     Mean Misclassified  Accuracy
# Neural-Network  0.264428          6976  0.821004
# 180Percent completed 17.982017982017982
# 200Error: 0.260840491553
#                    Mean Misclassified  Accuracy
# Neural-Network  0.26084          6919  0.822467
# 200Percent completed 19.98001998001998
# 220Error: 0.25789609639
#                     Mean Misclassified  Accuracy
# Neural-Network  0.257896          6858  0.824032
# 220Percent completed 21.978021978021978
# 240Error: 0.255506630268
#                     Mean Misclassified Accuracy
# Neural-Network  0.255507          6823  0.82493
# 240Percent completed 23.976023976023978
# 260Error: 0.253578086258
#                     Mean Misclassified  Accuracy
# Neural-Network  0.253578          6803  0.825443
# 260Percent completed 25.974025974025974
# 280Error: 0.252016743685
#                     Mean Misclassified  Accuracy
# Neural-Network  0.252017          6788  0.825828
# 280Percent completed 27.972027972027973
# 300Error: 0.250734235176
#                     Mean Misclassified  Accuracy
# Neural-Network  0.250734          6771  0.826264
# 300Percent completed 29.97002997002997
# 320Error: 0.24965128059
#                     Mean Misclassified  Accuracy
# Neural-Network  0.249651          6767  0.826367
# 320Percent completed 31.96803196803197
# 340Error: 0.248700480022
#                   Mean Misclassified Accuracy
# Neural-Network  0.2487          6740  0.82706
# 340Percent completed 33.96603396603397
# 360Error: 0.247828260422
#                     Mean Misclassified  Accuracy
# Neural-Network  0.247828          6706  0.827932
# 360Percent completed 35.964035964035965
# 380Error: 0.246995657607
#                     Mean Misclassified  Accuracy
# Neural-Network  0.246996          6683  0.828522
# 380Percent completed 37.96203796203796
# 400Error: 0.246177604734
#                     Mean Misclassified  Accuracy
# Neural-Network  0.246178          6652  0.829318
# 400Percent completed 39.96003996003996
# 420Error: 0.245360804219
#                     Mean Misclassified  Accuracy
# Neural-Network  0.245361          6638  0.829677
# 420Percent completed 41.95804195804196
# 440Error: 0.24454073019
#                     Mean Misclassified  Accuracy
# Neural-Network  0.244541          6589  0.830934
# 440Percent completed 43.956043956043956
# 460Error: 0.243718498767
#                     Mean Misclassified  Accuracy
# Neural-Network  0.243718          6569  0.831447
# 460Percent completed 45.95404595404595
# 480Error: 0.242898195012
#                     Mean Misclassified  Accuracy
# Neural-Network  0.242898          6527  0.832525
# 480Percent completed 47.952047952047955
# 500Error: 0.242084934525
#                     Mean Misclassified  Accuracy
# Neural-Network  0.242085          6518  0.832756
# 500Percent completed 49.95004995004995
# 520Error: 0.241283661747
#                     Mean Misclassified  Accuracy
# Neural-Network  0.241284          6508  0.833013
# 520Percent completed 51.94805194805195
# 540Error: 0.240498534771
#                     Mean Misclassified Accuracy
# Neural-Network  0.240499          6482  0.83368
# 540Percent completed 53.946053946053944
# 560Error: 0.239732707085
#                     Mean Misclassified  Accuracy
# Neural-Network  0.239733          6473  0.833911
# 560Percent completed 55.94405594405595
# 580Error: 0.238988341594
#                     Mean Misclassified  Accuracy
# Neural-Network  0.238988          6456  0.834347
# 580Percent completed 57.94205794205794
# 600Error: 0.238266738705
#                     Mean Misclassified  Accuracy
# Neural-Network  0.238267          6442  0.834706
# 600Percent completed 59.94005994005994
# 620Error: 0.237568504278
#                     Mean Misclassified Accuracy
# Neural-Network  0.237569          6436  0.83486
# 620Percent completed 61.938061938061935
# 640Error: 0.236893716453
#                     Mean Misclassified  Accuracy
# Neural-Network  0.236894          6435  0.834886
# 640Percent completed 63.93606393606394
# 660Error: 0.236242071995
#                     Mean Misclassified  Accuracy
# Neural-Network  0.236242          6422  0.835219
# 660Percent completed 65.93406593406593
# 680Error: 0.235613005699
#                     Mean Misclassified  Accuracy
# Neural-Network  0.235613          6407  0.835604
# 680Percent completed 67.93206793206794
# 700Error: 0.235005783169
#                     Mean Misclassified  Accuracy
# Neural-Network  0.235006          6396  0.835886
# 700Percent completed 69.93006993006993
# 720Error: 0.23441957037
#                    Mean Misclassified Accuracy
# Neural-Network  0.23442          6376   0.8364
# 720Percent completed 71.92807192807193
# 740Error: 0.233853484378
#                     Mean Misclassified  Accuracy
# Neural-Network  0.233853          6374  0.836451
# 740Percent completed 73.92607392607393
# 760Error: 0.233306629601
#                     Mean Misclassified  Accuracy
# Neural-Network  0.233307          6366  0.836656
# 760Percent completed 75.92407592407592
# 780Error: 0.232778123154
#                     Mean Misclassified  Accuracy
# Neural-Network  0.232778          6347  0.837144
# 780Percent completed 77.92207792207792
# 800Error: 0.232267112302
#                     Mean Misclassified  Accuracy
# Neural-Network  0.232267          6327  0.837657
# 800Percent completed 79.92007992007991
# 820Error: 0.231772786171
#                     Mean Misclassified  Accuracy
# Neural-Network  0.231773          6313  0.838016
# 820Percent completed 81.91808191808192
# 840Error: 0.231294383272
#                     Mean Misclassified Accuracy
# Neural-Network  0.231294          6300  0.83835
# 840Percent completed 83.91608391608392
# 860Error: 0.230831195929
#                     Mean Misclassified  Accuracy
# Neural-Network  0.230831          6296  0.838452
# 860Percent completed 85.91408591408592
# 880Error: 0.230382572329
#                     Mean Misclassified  Accuracy
# Neural-Network  0.230383          6280  0.838863
# 880Percent completed 87.91208791208791
# 900Error: 0.229947916689
#                     Mean Misclassified  Accuracy
# Neural-Network  0.229948          6269  0.839145
# 900Percent completed 89.91008991008991
# 920Error: 0.229526687885
#                     Mean Misclassified  Accuracy
# Neural-Network  0.229527          6264  0.839273
# 920Percent completed 91.9080919080919
# 940Error: 0.229118396812
#                     Mean Misclassified  Accuracy
# Neural-Network  0.229118          6260  0.839376
# 940Percent completed 93.9060939060939
# 960Error: 0.228722602713
#                     Mean Misclassified  Accuracy
# Neural-Network  0.228723          6243  0.839812
# 960Percent completed 95.90409590409591
# 980Error: 0.228338908715
#                     Mean Misclassified  Accuracy
# Neural-Network  0.228339          6236  0.839992
# 980Percent completed 97.9020979020979
# 995Error: 0.228058861953
#                     Mean Misclassified  Accuracy
# Neural-Network  0.228059          6232  0.840094
# 995Percent completed 99.4005994005994
# 996Error: 0.228040423989
#                    Mean Misclassified Accuracy
# Neural-Network  0.22804          6231  0.84012
# 996Percent completed 99.5004995004995
# 997Error: 0.228022013761
#                     Mean Misclassified  Accuracy
# Neural-Network  0.228022          6229  0.840171
# 997Percent completed 99.6003996003996
# 998Error: 0.228003633325
#                     Mean Misclassified  Accuracy
# Neural-Network  0.228004          6228  0.840197
# 998Percent completed 99.7002997002997
# 999Error: 0.227985280152
#                     Mean Misclassified  Accuracy
# Neural-Network  0.227985          6227  0.840223
# 999Percent completed 99.8001998001998
# 1000Error: 0.227966957163
#                     Mean Misclassified Accuracy
# Neural-Network  0.227967          6224   0.8403
# 1000Percent completed 99.9000999000999
# Error: 0.227966957163
# predicted [[ 0.01072359]
#  [ 0.13389793]
#  [ 0.52593519]
#  ...,
#  [ 0.10292475]
#  [ 0.05974165]
#  [ 0.0099722 ]]
# Predicted-Th [[0]
#  [0]
#  [1]
#  ...,
#  [0]
#  [0]
#  [0]]
# Actual [[0]
#  [0]
#  [1]
#  ...,
#  [0]
#  [0]
#  [0]]

# %%
#nn.loadWeights(folder="log/14-04-2017-15:05:49");
#nn.loadWeights(filename="weights.txt");
for i in range(1):
    nn.log_folder=nn.log_dir+"/"+nn.getTimestamp();
    nn.createDir(nn.log_folder);
    nn.no_of_iteration=5001;
    nn.learning_rate=0.0001;
    nn.train();
    nn.writeFinalWeights();
    result=nn.predict(x);
    print("predicted",result);
    print("Predicted-Th",nn.getThresholdValue(result));
    print("Actual",y);
    result=nn.predict(mtx_dummy_testds_norm);
    writeTestData(mtx_test_id,result,filenumber=nn.getMeanError());
    #writeTestData(mtx_test_id,nn.getThresholdValue(result),filename="predictions");
    print("=================["+str(i)+"]====================");
# Out:
# 0Error: 0.210627310375
#                     Mean Misclassified  Accuracy
# Neural-Network  0.210627          5748  0.852513
# 0Percent completed 0.0
# 20Error: 0.210605164615
#                     Mean Misclassified  Accuracy
# Neural-Network  0.210605          5747  0.852539
# 20Percent completed 0.39992001599680066
# 40Error: 0.210583047058
#                     Mean Misclassified  Accuracy
# Neural-Network  0.210583          5746  0.852565
# 40Percent completed 0.7998400319936013
# 60Error: 0.210560957644
#                     Mean Misclassified  Accuracy
# Neural-Network  0.210561          5747  0.852539
# 60Percent completed 1.1997600479904018
# 80Error: 0.210538896318
#                     Mean Misclassified  Accuracy
# Neural-Network  0.210539          5744  0.852616
# 80Percent completed 1.5996800639872026
# 100Error: 0.21051686302
#                     Mean Misclassified Accuracy
# Neural-Network  0.210517          5745  0.85259
# 100Percent completed 1.9996000799840032
# 120Error: 0.210494857694
#                     Mean Misclassified  Accuracy
# Neural-Network  0.210495          5746  0.852565
# 120Percent completed 2.3995200959808036
# 140Error: 0.210472880284
#                     Mean Misclassified  Accuracy
# Neural-Network  0.210473          5744  0.852616
# 140Percent completed 2.7994401119776047
# 160Error: 0.210450930731
#                     Mean Misclassified  Accuracy
# Neural-Network  0.210451          5743  0.852642
# 160Percent completed 3.1993601279744053
# 180Error: 0.210429008979
#                     Mean Misclassified Accuracy
# Neural-Network  0.210429          5745  0.85259
# 180Percent completed 3.599280143971206
# 200Error: 0.210407114971
#                     Mean Misclassified  Accuracy
# Neural-Network  0.210407          5744  0.852616
# 200Percent completed 3.9992001599680065
# 220Error: 0.21038524865
#                     Mean Misclassified  Accuracy
# Neural-Network  0.210385          5742  0.852667
# 220Percent completed 4.399120175964807
# 240Error: 0.210363409959
#                     Mean Misclassified  Accuracy
# Neural-Network  0.210363          5744  0.852616
# 240Percent completed 4.799040191961607
# 260Error: 0.210341598843
#                     Mean Misclassified  Accuracy
# Neural-Network  0.210342          5744  0.852616
# 260Percent completed 5.198960207958408
# 280Error: 0.210319815244
#                    Mean Misclassified Accuracy
# Neural-Network  0.21032          5745  0.85259
# 280Percent completed 5.598880223955209
# 300Error: 0.210298059106
#                     Mean Misclassified  Accuracy
# Neural-Network  0.210298          5744  0.852616
# 300Percent completed 5.9988002399520095
# 320Error: 0.210276330372
#                     Mean Misclassified  Accuracy
# Neural-Network  0.210276          5741  0.852693
# 320Percent completed 6.3987202559488106
# 340Error: 0.210254628986
#                     Mean Misclassified Accuracy
# Neural-Network  0.210255          5738  0.85277
# 340Percent completed 6.798640271945611
# 360Error: 0.210232954893
#                     Mean Misclassified Accuracy
# Neural-Network  0.210233          5738  0.85277
# 360Percent completed 7.198560287942412
# 380Error: 0.210211308034
#                     Mean Misclassified Accuracy
# Neural-Network  0.210211          5738  0.85277
# 380Percent completed 7.598480303939212
# 400Error: 0.210189688355
#                    Mean Misclassified  Accuracy
# Neural-Network  0.21019          5737  0.852796
# 400Percent completed 7.998400319936013
# 420Error: 0.2101680958
#                     Mean Misclassified  Accuracy
# Neural-Network  0.210168          5739  0.852744
# 420Percent completed 8.398320335932814
# 440Error: 0.210146530311
#                     Mean Misclassified Accuracy
# Neural-Network  0.210147          5738  0.85277
# 440Percent completed 8.798240351929614
# 460Error: 0.210124991834
#                     Mean Misclassified  Accuracy
# Neural-Network  0.210125          5737  0.852796
# 460Percent completed 9.198160367926414
# 480Error: 0.210103480311
#                     Mean Misclassified Accuracy
# Neural-Network  0.210103          5738  0.85277
# 480Percent completed 9.598080383923214
# 500Error: 0.210081995688
#                     Mean Misclassified  Accuracy
# Neural-Network  0.210082          5736  0.852821
# 500Percent completed 9.998000399920016
# 520Error: 0.210060537908
#                     Mean Misclassified  Accuracy
# Neural-Network  0.210061          5736  0.852821
# 520Percent completed 10.397920415916817
# 540Error: 0.210039106916
#                     Mean Misclassified  Accuracy
# Neural-Network  0.210039          5736  0.852821
# 540Percent completed 10.797840431913617
# 560Error: 0.210017702656
#                     Mean Misclassified  Accuracy
# Neural-Network  0.210018          5736  0.852821
# 560Percent completed 11.197760447910419
# 580Error: 0.209996325072
#                     Mean Misclassified  Accuracy
# Neural-Network  0.209996          5735  0.852847
# 580Percent completed 11.597680463907219
# 600Error: 0.209974974109
#                     Mean Misclassified  Accuracy
# Neural-Network  0.209975          5732  0.852924
# 600Percent completed 11.997600479904019
# 620Error: 0.209953649712
#                     Mean Misclassified  Accuracy
# Neural-Network  0.209954          5731  0.852949
# 620Percent completed 12.39752049590082
# 640Error: 0.209932351824
#                     Mean Misclassified  Accuracy
# Neural-Network  0.209932          5731  0.852949
# 640Percent completed 12.797440511897621
# 660Error: 0.209911080391
#                     Mean Misclassified  Accuracy
# Neural-Network  0.209911          5729  0.853001
# 660Percent completed 13.197360527894421
# 680Error: 0.209889835358
#                    Mean Misclassified  Accuracy
# Neural-Network  0.20989          5726  0.853078
# 680Percent completed 13.597280543891221
# 700Error: 0.209868616669
#                     Mean Misclassified  Accuracy
# Neural-Network  0.209869          5728  0.853026
# 700Percent completed 13.997200559888022
# 720Error: 0.20984742427
#                     Mean Misclassified  Accuracy
# Neural-Network  0.209847          5728  0.853026
# 720Percent completed 14.397120575884824
# 740Error: 0.209826258106
#                     Mean Misclassified  Accuracy
# Neural-Network  0.209826          5728  0.853026
# 740Percent completed 14.797040591881624
# 760Error: 0.209805118121
#                     Mean Misclassified  Accuracy
# Neural-Network  0.209805          5727  0.853052
# 760Percent completed 15.196960607878424
# 780Error: 0.209784004263
#                     Mean Misclassified  Accuracy
# Neural-Network  0.209784          5727  0.853052
# 780Percent completed 15.596880623875226
# 800Error: 0.209762916475
#                     Mean Misclassified  Accuracy
# Neural-Network  0.209763          5727  0.853052
# 800Percent completed 15.996800639872026
# 820Error: 0.209741854704
#                     Mean Misclassified  Accuracy
# Neural-Network  0.209742          5725  0.853103
# 820Percent completed 16.396720655868826
# 840Error: 0.209720818896
#                     Mean Misclassified  Accuracy
# Neural-Network  0.209721          5725  0.853103
# 840Percent completed 16.796640671865628
# 860Error: 0.209699808997
#                   Mean Misclassified  Accuracy
# Neural-Network  0.2097          5723  0.853155
# 860Percent completed 17.196560687862426
# 880Error: 0.209678824953
#                     Mean Misclassified  Accuracy
# Neural-Network  0.209679          5723  0.853155
# 880Percent completed 17.59648070385923
# 900Error: 0.20965786671
#                     Mean Misclassified  Accuracy
# Neural-Network  0.209658          5726  0.853078
# 900Percent completed 17.99640071985603
# 920Error: 0.209636934216
#                     Mean Misclassified  Accuracy
# Neural-Network  0.209637          5721  0.853206
# 920Percent completed 18.39632073585283
# 940Error: 0.209616027416
#                     Mean Misclassified  Accuracy
# Neural-Network  0.209616          5721  0.853206
# 940Percent completed 18.79624075184963
# 960Error: 0.209595146258
#                     Mean Misclassified  Accuracy
# Neural-Network  0.209595          5717  0.853309
# 960Percent completed 19.19616076784643
# 980Error: 0.209574290689
#                     Mean Misclassified  Accuracy
# Neural-Network  0.209574          5718  0.853283
# 980Percent completed 19.59608078384323
# 1000Error: 0.209553460656
#                     Mean Misclassified  Accuracy
# Neural-Network  0.209553          5718  0.853283
# 1000Percent completed 19.996000799840033
# 1020Error: 0.209532656107
#                     Mean Misclassified Accuracy
# Neural-Network  0.209533          5715  0.85336
# 1020Percent completed 20.39592081583683
# 1040Error: 0.20951187699
#                     Mean Misclassified  Accuracy
# Neural-Network  0.209512          5714  0.853386
# 1040Percent completed 20.795840831833633
# 1060Error: 0.209491123253
#                     Mean Misclassified  Accuracy
# Neural-Network  0.209491          5716  0.853334
# 1060Percent completed 21.195760847830435
# 1080Error: 0.209470394844
#                    Mean Misclassified  Accuracy
# Neural-Network  0.20947          5716  0.853334
# 1080Percent completed 21.595680863827234
# 1100Error: 0.209449691711
#                    Mean Misclassified Accuracy
# Neural-Network  0.20945          5715  0.85336
# 1100Percent completed 21.995600879824035
# 1120Error: 0.209429013805
#                     Mean Misclassified  Accuracy
# Neural-Network  0.209429          5716  0.853334
# 1120Percent completed 22.395520895820837
# 1140Error: 0.209408361072
#                     Mean Misclassified  Accuracy
# Neural-Network  0.209408          5718  0.853283
# 1140Percent completed 22.795440911817636
# 1160Error: 0.209387733464
#                     Mean Misclassified  Accuracy
# Neural-Network  0.209388          5718  0.853283
# 1160Percent completed 23.195360927814438
# 1180Error: 0.209367130929
#                     Mean Misclassified  Accuracy
# Neural-Network  0.209367          5719  0.853257
# 1180Percent completed 23.595280943811236
# 1200Error: 0.209346553418
#                     Mean Misclassified  Accuracy
# Neural-Network  0.209347          5719  0.853257
# 1200Percent completed 23.995200959808038
# 1220Error: 0.209326000879
#                     Mean Misclassified  Accuracy
# Neural-Network  0.209326          5717  0.853309
# 1220Percent completed 24.39512097580484
# 1240Error: 0.209305473265
#                     Mean Misclassified  Accuracy
# Neural-Network  0.209305          5717  0.853309
# 1240Percent completed 24.79504099180164
# 1260Error: 0.209284970526
#                     Mean Misclassified  Accuracy
# Neural-Network  0.209285          5717  0.853309
# 1260Percent completed 25.19496100779844
# 1280Error: 0.209264492612
#                     Mean Misclassified  Accuracy
# Neural-Network  0.209264          5717  0.853309
# 1280Percent completed 25.594881023795242
# 1300Error: 0.209244039475
#                     Mean Misclassified Accuracy
# Neural-Network  0.209244          5715  0.85336
# 1300Percent completed 25.99480103979204
# 1320Error: 0.209223611067
#                     Mean Misclassified Accuracy
# Neural-Network  0.209224          5715  0.85336
# 1320Percent completed 26.394721055788843
# 1340Error: 0.20920320734
#                     Mean Misclassified  Accuracy
# Neural-Network  0.209203          5716  0.853334
# 1340Percent completed 26.794641071785644
# 1360Error: 0.209182828245
#                     Mean Misclassified  Accuracy
# Neural-Network  0.209183          5714  0.853386
# 1360Percent completed 27.194561087782443
# 1380Error: 0.209162473736
#                     Mean Misclassified Accuracy
# Neural-Network  0.209162          5715  0.85336
# 1380Percent completed 27.594481103779245
# 1400Error: 0.209142143765
#                     Mean Misclassified Accuracy
# Neural-Network  0.209142          5715  0.85336
# 1400Percent completed 27.994401119776043
# 1420Error: 0.209121838285
#                     Mean Misclassified Accuracy
# Neural-Network  0.209122          5715  0.85336
# 1420Percent completed 28.394321135772845
# 1440Error: 0.20910155725
#                     Mean Misclassified Accuracy
# Neural-Network  0.209102          5715  0.85336
# 1440Percent completed 28.794241151769647
# 1460Error: 0.209081300615
#                     Mean Misclassified  Accuracy
# Neural-Network  0.209081          5713  0.853411
# 1460Percent completed 29.194161167766445
# 1480Error: 0.209061068332
#                     Mean Misclassified  Accuracy
# Neural-Network  0.209061          5712  0.853437
# 1480Percent completed 29.594081183763247
# 1500Error: 0.209040860357
#                     Mean Misclassified  Accuracy
# Neural-Network  0.209041          5712  0.853437
# 1500Percent completed 29.99400119976005
# 1520Error: 0.209020676644
#                     Mean Misclassified  Accuracy
# Neural-Network  0.209021          5713  0.853411
# 1520Percent completed 30.393921215756848
# 1540Error: 0.209000517149
#                     Mean Misclassified  Accuracy
# Neural-Network  0.209001          5713  0.853411
# 1540Percent completed 30.79384123175365
# 1560Error: 0.208980381827
#                    Mean Misclassified  Accuracy
# Neural-Network  0.20898          5714  0.853386
# 1560Percent completed 31.19376124775045
# 1580Error: 0.208960270634
#                    Mean Misclassified  Accuracy
# Neural-Network  0.20896          5712  0.853437
# 1580Percent completed 31.59368126374725
# 1600Error: 0.208940183526
#                    Mean Misclassified  Accuracy
# Neural-Network  0.20894          5712  0.853437
# 1600Percent completed 31.993601279744052
# 1620Error: 0.20892012046
#                    Mean Misclassified Accuracy
# Neural-Network  0.20892          5715  0.85336
# 1620Percent completed 32.393521295740854
# 1640Error: 0.208900081393
#                   Mean Misclassified  Accuracy
# Neural-Network  0.2089          5714  0.853386
# 1640Percent completed 32.79344131173765
# 1660Error: 0.208880066281
#                    Mean Misclassified  Accuracy
# Neural-Network  0.20888          5713  0.853411
# 1660Percent completed 33.19336132773445
# 1680Error: 0.208860075083
#                    Mean Misclassified  Accuracy
# Neural-Network  0.20886          5714  0.853386
# 1680Percent completed 33.593281343731256
# 1700Error: 0.208840107757
#                    Mean Misclassified  Accuracy
# Neural-Network  0.20884          5713  0.853411
# 1700Percent completed 33.993201359728054
# 1720Error: 0.20882016426
#                    Mean Misclassified Accuracy
# Neural-Network  0.20882          5715  0.85336
# 1720Percent completed 34.39312137572485
# 1740Error: 0.208800244551
#                   Mean Misclassified  Accuracy
# Neural-Network  0.2088          5716  0.853334
# 1740Percent completed 34.79304139172166
# 1760Error: 0.20878034859
#                    Mean Misclassified  Accuracy
# Neural-Network  0.20878          5718  0.853283
# 1760Percent completed 35.19296140771846
# 1780Error: 0.208760476335
#                    Mean Misclassified  Accuracy
# Neural-Network  0.20876          5719  0.853257
# 1780Percent completed 35.592881423715255
# 1800Error: 0.208740627746
#                     Mean Misclassified  Accuracy
# Neural-Network  0.208741          5717  0.853309
# 1800Percent completed 35.99280143971206
# 1820Error: 0.208720802783
#                     Mean Misclassified  Accuracy
# Neural-Network  0.208721          5719  0.853257
# 1820Percent completed 36.39272145570886
# 1840Error: 0.208701001406
#                     Mean Misclassified  Accuracy
# Neural-Network  0.208701          5718  0.853283
# 1840Percent completed 36.79264147170566
# 1860Error: 0.208681223577
#                     Mean Misclassified  Accuracy
# Neural-Network  0.208681          5716  0.853334
# 1860Percent completed 37.19256148770246
# 1880Error: 0.208661469255
#                     Mean Misclassified Accuracy
# Neural-Network  0.208661          5715  0.85336
# 1880Percent completed 37.59248150369926
# 1900Error: 0.208641738402
#                     Mean Misclassified  Accuracy
# Neural-Network  0.208642          5714  0.853386
# 1900Percent completed 37.99240151969606
# 1920Error: 0.20862203098
#                     Mean Misclassified  Accuracy
# Neural-Network  0.208622          5713  0.853411
# 1920Percent completed 38.39232153569286
# 1940Error: 0.20860234695
#                     Mean Misclassified  Accuracy
# Neural-Network  0.208602          5712  0.853437
# 1940Percent completed 38.79224155168966
# 1960Error: 0.208582686275
#                     Mean Misclassified  Accuracy
# Neural-Network  0.208583          5710  0.853488
# 1960Percent completed 39.19216156768646
# 1980Error: 0.208563048918
#                     Mean Misclassified  Accuracy
# Neural-Network  0.208563          5710  0.853488
# 1980Percent completed 39.59208158368326
# 2000Error: 0.208543434841
#                     Mean Misclassified Accuracy
# Neural-Network  0.208543          5708  0.85354
# 2000Percent completed 39.992001599680066
# 2020Error: 0.208523844007
#                     Mean Misclassified Accuracy
# Neural-Network  0.208524          5708  0.85354
# 2020Percent completed 40.391921615676864
# 2040Error: 0.20850427638
#                     Mean Misclassified  Accuracy
# Neural-Network  0.208504          5709  0.853514
# 2040Percent completed 40.79184163167366
# 2060Error: 0.208484731923
#                     Mean Misclassified  Accuracy
# Neural-Network  0.208485          5709  0.853514
# 2060Percent completed 41.19176164767047
# 2080Error: 0.208465210601
#                     Mean Misclassified Accuracy
# Neural-Network  0.208465          5708  0.85354
# 2080Percent completed 41.591681663667266
# 2100Error: 0.208445712378
#                     Mean Misclassified Accuracy
# Neural-Network  0.208446          5708  0.85354
# 2100Percent completed 41.991601679664065
# 2120Error: 0.208426237219
#                     Mean Misclassified  Accuracy
# Neural-Network  0.208426          5706  0.853591
# 2120Percent completed 42.39152169566087
# 2140Error: 0.208406785089
#                     Mean Misclassified  Accuracy
# Neural-Network  0.208407          5705  0.853617
# 2140Percent completed 42.79144171165767
# 2160Error: 0.208387355952
#                     Mean Misclassified  Accuracy
# Neural-Network  0.208387          5705  0.853617
# 2160Percent completed 43.19136172765447
# 2180Error: 0.208367949775
#                     Mean Misclassified  Accuracy
# Neural-Network  0.208368          5704  0.853642
# 2180Percent completed 43.59128174365127
# 2200Error: 0.208348566523
#                     Mean Misclassified  Accuracy
# Neural-Network  0.208349          5701  0.853719
# 2200Percent completed 43.99120175964807
# 2220Error: 0.208329206162
#                     Mean Misclassified  Accuracy
# Neural-Network  0.208329          5700  0.853745
# 2220Percent completed 44.39112177564487
# 2240Error: 0.208309868658
#                    Mean Misclassified  Accuracy
# Neural-Network  0.20831          5700  0.853745
# 2240Percent completed 44.791041791641675
# 2260Error: 0.208290553979
#                     Mean Misclassified  Accuracy
# Neural-Network  0.208291          5700  0.853745
# 2260Percent completed 45.19096180763847
# 2280Error: 0.208271262091
#                     Mean Misclassified  Accuracy
# Neural-Network  0.208271          5700  0.853745
# 2280Percent completed 45.59088182363527
# 2300Error: 0.20825199296
#                     Mean Misclassified  Accuracy
# Neural-Network  0.208252          5698  0.853796
# 2300Percent completed 45.99080183963208
# 2320Error: 0.208232746555
#                     Mean Misclassified  Accuracy
# Neural-Network  0.208233          5697  0.853822
# 2320Percent completed 46.390721855628875
# 2340Error: 0.208213522842
#                     Mean Misclassified  Accuracy
# Neural-Network  0.208214          5695  0.853873
# 2340Percent completed 46.790641871625674
# 2360Error: 0.20819432179
#                     Mean Misclassified  Accuracy
# Neural-Network  0.208194          5695  0.853873
# 2360Percent completed 47.19056188762247
# 2380Error: 0.208175143367
#                     Mean Misclassified  Accuracy
# Neural-Network  0.208175          5694  0.853899
# 2380Percent completed 47.59048190361928
# 2400Error: 0.208155987541
#                     Mean Misclassified  Accuracy
# Neural-Network  0.208156          5694  0.853899
# 2400Percent completed 47.990401919616076
# 2420Error: 0.20813685428
#                     Mean Misclassified Accuracy
# Neural-Network  0.208137          5692  0.85395
# 2420Percent completed 48.390321935612874
# 2440Error: 0.208117743553
#                     Mean Misclassified Accuracy
# Neural-Network  0.208118          5692  0.85395
# 2440Percent completed 48.79024195160968
# 2460Error: 0.208098655329
#                     Mean Misclassified  Accuracy
# Neural-Network  0.208099          5693  0.853925
# 2460Percent completed 49.19016196760648
# 2480Error: 0.208079589578
#                    Mean Misclassified  Accuracy
# Neural-Network  0.20808          5691  0.853976
# 2480Percent completed 49.59008198360328
# 2500Error: 0.208060546267
#                     Mean Misclassified Accuracy
# Neural-Network  0.208061          5692  0.85395
# 2500Percent completed 49.99000199960008
# 2520Error: 0.208041525368
#                     Mean Misclassified  Accuracy
# Neural-Network  0.208042          5691  0.853976
# 2520Percent completed 50.38992201559688
# 2540Error: 0.208022526849
#                     Mean Misclassified  Accuracy
# Neural-Network  0.208023          5691  0.853976
# 2540Percent completed 50.78984203159368
# 2560Error: 0.208003550681
#                     Mean Misclassified  Accuracy
# Neural-Network  0.208004          5691  0.853976
# 2560Percent completed 51.189762047590484
# 2580Error: 0.207984596833
#                     Mean Misclassified  Accuracy
# Neural-Network  0.207985          5693  0.853925
# 2580Percent completed 51.58968206358728
# 2600Error: 0.207965665277
#                     Mean Misclassified  Accuracy
# Neural-Network  0.207966          5693  0.853925
# 2600Percent completed 51.98960207958408
# 2620Error: 0.207946755981
#                     Mean Misclassified  Accuracy
# Neural-Network  0.207947          5694  0.853899
# 2620Percent completed 52.38952209558089
# 2640Error: 0.207927868917
#                     Mean Misclassified Accuracy
# Neural-Network  0.207928          5692  0.85395
# 2640Percent completed 52.789442111577685
# 2660Error: 0.207909004056
#                     Mean Misclassified  Accuracy
# Neural-Network  0.207909          5689  0.854027
# 2660Percent completed 53.18936212757448
# 2680Error: 0.207890161368
#                    Mean Misclassified  Accuracy
# Neural-Network  0.20789          5689  0.854027
# 2680Percent completed 53.58928214357129
# 2700Error: 0.207871340825
#                     Mean Misclassified  Accuracy
# Neural-Network  0.207871          5688  0.854053
# 2700Percent completed 53.98920215956809
# 2720Error: 0.207852542397
#                     Mean Misclassified  Accuracy
# Neural-Network  0.207853          5688  0.854053
# 2720Percent completed 54.389122175564886
# 2740Error: 0.207833766056
#                     Mean Misclassified  Accuracy
# Neural-Network  0.207834          5686  0.854104
# 2740Percent completed 54.78904219156169
# 2760Error: 0.207815011774
#                     Mean Misclassified  Accuracy
# Neural-Network  0.207815          5686  0.854104
# 2760Percent completed 55.18896220755849
# 2780Error: 0.207796279521
#                     Mean Misclassified Accuracy
# Neural-Network  0.207796          5685  0.85413
# 2780Percent completed 55.58888222355529
# 2800Error: 0.207777569271
#                     Mean Misclassified  Accuracy
# Neural-Network  0.207778          5684  0.854155
# 2800Percent completed 55.988802239552086
# 2820Error: 0.207758880994
#                     Mean Misclassified  Accuracy
# Neural-Network  0.207759          5681  0.854232
# 2820Percent completed 56.38872225554889
# 2840Error: 0.207740214662
#                    Mean Misclassified  Accuracy
# Neural-Network  0.20774          5683  0.854181
# 2840Percent completed 56.78864227154569
# 2860Error: 0.207721570248
#                     Mean Misclassified  Accuracy
# Neural-Network  0.207722          5680  0.854258
# 2860Percent completed 57.18856228754249
# 2880Error: 0.207702947724
#                     Mean Misclassified  Accuracy
# Neural-Network  0.207703          5680  0.854258
# 2880Percent completed 57.588482303539294
# 2900Error: 0.207684347062
#                     Mean Misclassified  Accuracy
# Neural-Network  0.207684          5678  0.854309
# 2900Percent completed 57.98840231953609
# 2920Error: 0.207665768234
#                     Mean Misclassified  Accuracy
# Neural-Network  0.207666          5678  0.854309
# 2920Percent completed 58.38832233553289
# 2940Error: 0.207647211213
#                     Mean Misclassified  Accuracy
# Neural-Network  0.207647          5678  0.854309
# 2940Percent completed 58.788242351529696
# 2960Error: 0.207628675971
#                     Mean Misclassified  Accuracy
# Neural-Network  0.207629          5677  0.854335
# 2960Percent completed 59.188162367526495
# 2980Error: 0.207610162482
#                    Mean Misclassified  Accuracy
# Neural-Network  0.20761          5677  0.854335
# 2980Percent completed 59.58808238352329
# 3000Error: 0.207591670717
#                     Mean Misclassified  Accuracy
# Neural-Network  0.207592          5677  0.854335
# 3000Percent completed 59.9880023995201
# 3020Error: 0.20757320065
#                     Mean Misclassified  Accuracy
# Neural-Network  0.207573          5677  0.854335
# 3020Percent completed 60.3879224155169
# 3040Error: 0.207554752253
#                     Mean Misclassified  Accuracy
# Neural-Network  0.207555          5675  0.854386
# 3040Percent completed 60.787842431513695
# 3060Error: 0.2075363255
#                     Mean Misclassified  Accuracy
# Neural-Network  0.207536          5678  0.854309
# 3060Percent completed 61.1877624475105
# 3080Error: 0.207517920363
#                     Mean Misclassified  Accuracy
# Neural-Network  0.207518          5678  0.854309
# 3080Percent completed 61.5876824635073
# 3100Error: 0.207499536815
#                   Mean Misclassified  Accuracy
# Neural-Network  0.2075          5679  0.854284
# 3100Percent completed 61.9876024795041
# 3120Error: 0.20748117483
#                     Mean Misclassified  Accuracy
# Neural-Network  0.207481          5679  0.854284
# 3120Percent completed 62.3875224955009
# 3140Error: 0.20746283438
#                     Mean Misclassified  Accuracy
# Neural-Network  0.207463          5679  0.854284
# 3140Percent completed 62.7874425114977
# 3160Error: 0.207444515439
#                     Mean Misclassified  Accuracy
# Neural-Network  0.207445          5679  0.854284
# 3160Percent completed 63.1873625274945
# 3180Error: 0.207426217981
#                     Mean Misclassified  Accuracy
# Neural-Network  0.207426          5680  0.854258
# 3180Percent completed 63.5872825434913
# 3200Error: 0.207407941977
#                     Mean Misclassified  Accuracy
# Neural-Network  0.207408          5681  0.854232
# 3200Percent completed 63.987202559488104
# 3220Error: 0.207389687403
#                    Mean Misclassified  Accuracy
# Neural-Network  0.20739          5681  0.854232
# 3220Percent completed 64.38712257548491
# 3240Error: 0.20737145423
#                     Mean Misclassified  Accuracy
# Neural-Network  0.207371          5681  0.854232
# 3240Percent completed 64.78704259148171
# 3260Error: 0.207353242433
#                     Mean Misclassified  Accuracy
# Neural-Network  0.207353          5681  0.854232
# 3260Percent completed 65.1869626074785
# 3280Error: 0.207335051985
#                     Mean Misclassified  Accuracy
# Neural-Network  0.207335          5681  0.854232
# 3280Percent completed 65.5868826234753
# 3300Error: 0.207316882859
#                     Mean Misclassified  Accuracy
# Neural-Network  0.207317          5681  0.854232
# 3300Percent completed 65.9868026394721
# 3320Error: 0.207298735029
#                     Mean Misclassified  Accuracy
# Neural-Network  0.207299          5680  0.854258
# 3320Percent completed 66.3867226554689
# 3340Error: 0.207280608469
#                     Mean Misclassified  Accuracy
# Neural-Network  0.207281          5678  0.854309
# 3340Percent completed 66.78664267146571
# 3360Error: 0.207262503151
#                     Mean Misclassified  Accuracy
# Neural-Network  0.207263          5677  0.854335
# 3360Percent completed 67.18656268746251
# 3380Error: 0.207244419049
#                     Mean Misclassified  Accuracy
# Neural-Network  0.207244          5677  0.854335
# 3380Percent completed 67.58648270345931
# 3400Error: 0.207226356137
#                     Mean Misclassified  Accuracy
# Neural-Network  0.207226          5677  0.854335
# 3400Percent completed 67.98640271945611
# 3420Error: 0.207208314389
#                     Mean Misclassified  Accuracy
# Neural-Network  0.207208          5678  0.854309
# 3420Percent completed 68.38632273545291
# 3440Error: 0.207190293777
#                    Mean Misclassified  Accuracy
# Neural-Network  0.20719          5678  0.854309
# 3440Percent completed 68.7862427514497
# 3460Error: 0.207172294276
#                     Mean Misclassified  Accuracy
# Neural-Network  0.207172          5678  0.854309
# 3460Percent completed 69.1861627674465
# 3480Error: 0.207154315858
#                     Mean Misclassified  Accuracy
# Neural-Network  0.207154          5677  0.854335
# 3480Percent completed 69.58608278344332
# 3500Error: 0.207136358498
#                     Mean Misclassified  Accuracy
# Neural-Network  0.207136          5677  0.854335
# 3500Percent completed 69.98600279944012
# 3520Error: 0.207118422169
#                     Mean Misclassified  Accuracy
# Neural-Network  0.207118          5676  0.854361
# 3520Percent completed 70.38592281543691
# 3540Error: 0.207100506845
#                     Mean Misclassified  Accuracy
# Neural-Network  0.207101          5675  0.854386
# 3540Percent completed 70.78584283143371
# 3560Error: 0.207082612498
#                     Mean Misclassified  Accuracy
# Neural-Network  0.207083          5676  0.854361
# 3560Percent completed 71.18576284743051
# 3580Error: 0.207064739103
#                     Mean Misclassified  Accuracy
# Neural-Network  0.207065          5676  0.854361
# 3580Percent completed 71.58568286342731
# 3600Error: 0.207046886633
#                     Mean Misclassified  Accuracy
# Neural-Network  0.207047          5677  0.854335
# 3600Percent completed 71.98560287942412
# 3620Error: 0.207029055061
#                     Mean Misclassified  Accuracy
# Neural-Network  0.207029          5677  0.854335
# 3620Percent completed 72.38552289542092
# 3640Error: 0.207011244361
#                     Mean Misclassified  Accuracy
# Neural-Network  0.207011          5674  0.854412
# 3640Percent completed 72.78544291141772
# 3660Error: 0.206993454507
#                     Mean Misclassified  Accuracy
# Neural-Network  0.206993          5673  0.854438
# 3660Percent completed 73.18536292741452
# 3680Error: 0.206975685471
#                     Mean Misclassified  Accuracy
# Neural-Network  0.206976          5671  0.854489
# 3680Percent completed 73.58528294341131
# 3700Error: 0.206957937227
#                     Mean Misclassified  Accuracy
# Neural-Network  0.206958          5670  0.854515
# 3700Percent completed 73.98520295940811
# 3720Error: 0.206940209749
#                    Mean Misclassified  Accuracy
# Neural-Network  0.20694          5670  0.854515
# 3720Percent completed 74.38512297540493
# 3740Error: 0.206922503009
#                     Mean Misclassified  Accuracy
# Neural-Network  0.206923          5671  0.854489
# 3740Percent completed 74.78504299140172
# 3760Error: 0.206904816982
#                     Mean Misclassified  Accuracy
# Neural-Network  0.206905          5671  0.854489
# 3760Percent completed 75.18496300739852
# 3780Error: 0.206887151639
#                     Mean Misclassified  Accuracy
# Neural-Network  0.206887          5671  0.854489
# 3780Percent completed 75.58488302339532
# 3800Error: 0.206869506956
#                    Mean Misclassified  Accuracy
# Neural-Network  0.20687          5672  0.854463
# 3800Percent completed 75.98480303939212
# 3820Error: 0.206851882904
#                     Mean Misclassified  Accuracy
# Neural-Network  0.206852          5673  0.854438
# 3820Percent completed 76.38472305538892
# 3840Error: 0.206834279457
#                     Mean Misclassified  Accuracy
# Neural-Network  0.206834          5673  0.854438
# 3840Percent completed 76.78464307138572
# 3860Error: 0.206816696589
#                     Mean Misclassified  Accuracy
# Neural-Network  0.206817          5672  0.854463
# 3860Percent completed 77.18456308738253
# 3880Error: 0.206799134272
#                     Mean Misclassified  Accuracy
# Neural-Network  0.206799          5673  0.854438
# 3880Percent completed 77.58448310337933
# 3900Error: 0.206781592479
#                     Mean Misclassified  Accuracy
# Neural-Network  0.206782          5673  0.854438
# 3900Percent completed 77.98440311937613
# 3920Error: 0.206764071184
#                     Mean Misclassified  Accuracy
# Neural-Network  0.206764          5674  0.854412
# 3920Percent completed 78.38432313537292
# 3940Error: 0.206746570359
#                     Mean Misclassified  Accuracy
# Neural-Network  0.206747          5675  0.854386
# 3940Percent completed 78.78424315136972
# 3960Error: 0.206729089978
#                     Mean Misclassified  Accuracy
# Neural-Network  0.206729          5675  0.854386
# 3960Percent completed 79.18416316736652
# 3980Error: 0.206711630013
#                     Mean Misclassified  Accuracy
# Neural-Network  0.206712          5674  0.854412
# 3980Percent completed 79.58408318336333
# 4000Error: 0.206694190437
#                     Mean Misclassified  Accuracy
# Neural-Network  0.206694          5673  0.854438
# 4000Percent completed 79.98400319936013
# 4020Error: 0.206676771224
#                     Mean Misclassified  Accuracy
# Neural-Network  0.206677          5673  0.854438
# 4020Percent completed 80.38392321535693
# 4040Error: 0.206659372346
#                     Mean Misclassified  Accuracy
# Neural-Network  0.206659          5672  0.854463
# 4040Percent completed 80.78384323135373
# 4060Error: 0.206641993776
#                     Mean Misclassified  Accuracy
# Neural-Network  0.206642          5672  0.854463
# 4060Percent completed 81.18376324735053
# 4080Error: 0.206624635487
#                     Mean Misclassified  Accuracy
# Neural-Network  0.206625          5672  0.854463
# 4080Percent completed 81.58368326334733
# 4100Error: 0.206607297451
#                     Mean Misclassified  Accuracy
# Neural-Network  0.206607          5672  0.854463
# 4100Percent completed 81.98360327934414
# 4120Error: 0.206589979641
#                    Mean Misclassified  Accuracy
# Neural-Network  0.20659          5670  0.854515
# 4120Percent completed 82.38352329534094
# 4140Error: 0.20657268203
#                     Mean Misclassified  Accuracy
# Neural-Network  0.206573          5671  0.854489
# 4140Percent completed 82.78344331133773
# 4160Error: 0.206555404591
#                     Mean Misclassified  Accuracy
# Neural-Network  0.206555          5671  0.854489
# 4160Percent completed 83.18336332733453
# 4180Error: 0.206538147296
#                     Mean Misclassified  Accuracy
# Neural-Network  0.206538          5671  0.854489
# 4180Percent completed 83.58328334333133
# 4200Error: 0.206520910117
#                     Mean Misclassified  Accuracy
# Neural-Network  0.206521          5670  0.854515
# 4200Percent completed 83.98320335932813

# %%
result=nn.forwardPropogation(x);
a=nn.getThresholdValue(result);    
for i in range (100):
    if(a[i] != y[i]):
        print(result[i],"--",a[i]," : ", y[i])
# Out:
# [ 0.54575265] -- [1]  :  [0]
# [ 0.6476731] -- [1]  :  [0]

# %%
Error: 0.171002924555
predicted [[ 0.01158368]
 [ 0.16169772]
 [ 0.79267492]
 ..., 
 [ 0.00216001]
 [ 0.00571994]
 [ 0.00000743]]

-------------------------
Error: 0.205330880646
[[ 0.00363059]
 [ 0.06083415]
 [ 0.48931599]
 ..., 
 [ 0.03094003]
 [ 0.02798609]
 [ 0.00329329]]

Error: 0.227966957163
predicted [[ 0.01072359]
 [ 0.13389793]
 [ 0.52593519]
 ..., 
 [ 0.10292475]
 [ 0.05974165]
 [ 0.0099722 ]]
Predicted-Th [[0]
              
              
predicted [[ 0.00907586]
 [ 0.14776174]
 [ 0.61484095]
 ..., 
 [ 0.05793402]
 [ 0.04302789]
 [ 0.0047609 ]]
              
Error: 0.210627310375
predicted [[ 0.00570752]
 [ 0.15194193]
 [ 0.64953007]
 ..., 
 [ 0.0388894 ]
 [ 0.03060381]
 [ 0.00254692]]
