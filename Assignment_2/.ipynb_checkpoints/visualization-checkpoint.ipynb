# %%
import pandas;
import seaborn as sb;
import numpy as np;
import matplotlib.pyplot as plt
# %matplotlib inline
np.set_printoptions(suppress=True)

def readCSVFile(file):
    data=pandas.read_csv(file,",",header=0, na_values='?', skipinitialspace=True);
    return data;
    pass;
def readTrainData(dataset):    
    return dataset.ix[:,1:-1], dataset.ix[:,-1:];
    pass;

def readTestData(dataset):    
    return dataset.ix[:,1:],dataset.ix[:,0:1];
    pass;

def normalizePhi(unNormalizedPhi,last_col_bias=False):    
    #assuming last column as bias column
    no_of_column=len(unNormalizedPhi[0]);
    phi=np.array(unNormalizedPhi);
    print("Normalizing Phi...");  
    std=phi.std(0);
    mean=phi.mean(0);    
    std[no_of_column-1]=1;
    mean[no_of_column-1]=0;
    #phi_normalize=(phi-mean)/std;    
    
    max_vector=phi.max(axis=0)
    phi_normalize=phi/max_vector;    
    
    print("Normalization done.");
    return phi_normalize;
    pass;

def writeTestData(test_id,ystar,filenumber=0):    
    fo = open("sampleSubmission-"+str(filenumber)+".csv", "w");               
    fo.write("id,salary\n");
    m=len(ystar);
    for i in range(m):
        fo.write(str(test_id[i][0])+","+str(ystar[i][0])+"\n");
    fo.close();
    pass;

def dropColumns(dataframe,colList):
    for c in colList:
        dataframe.drop([c], axis = 1, inplace = True);
    pass;

def addColByCategory(dataset):
    return pandas.get_dummies(dataset);
    pass;

def categoryToNumber(dataset,categoryList):
    for c in categoryList:
        if (c in dataset):            
            dataset[c]=pandas.get_dummies(dataset[c]).values.argmax(1);        
    return dataset;
    pass;
    

def handleCategoryData(dataset,categoryList=None,byNumber=False):
    if(byNumber):
        return categoryToNumber(dataset,categoryList)
    else:
        return addColByCategory(dataset);
def findMostFrequentCount(dataset):
    #arr=dataset;
    #axis = 0
    #u, indices = np.unique(arr, return_inverse=True)
    #print(u);
    #u[np.argmax(np.apply_along_axis(np.bincount, axis, indices.reshape(arr.shape),None, np.max(indices) + 1), axis=axis)]
    x = np.array([0, 1, 1, 3, 2, 1, 2, 3]);
    w=np.bincount(dataset[:,1].astype(int))#work-class: Private
    o=np.bincount(dataset[:,6].astype(int))#occupation: Married-civ-spouse
    c=np.bincount(dataset[:,13].astype(int))#country : US
    pass;

def fillNanValue(dataframe,col,value):
    if (col in dataframe):
        dataframe[col].fillna(value, inplace=True);
    pass;

def imputeUnknowValue(dataframe):
    #by most frequent value;
    fillNanValue(dataframe,"workclass","Private");
    fillNanValue(dataframe,"occupation","Craft-repair");
    fillNanValue(dataframe,"native-country","United-States");
    pass;

def addRemainingCol(colList,dataframe,rowCount):
    i=0;
    for c in colList:
        if( c not in dataframe):
            dataframe.insert(i, c, 0);
        i+=1;
    pass;

# %%
#--settings--
pandas.set_option('display.max_columns', None);
#---init---
dir="data/"
trainFile=dir+"train.csv";
testFile=dir+"kaggle_test_data.csv";
categoryList=["workclass","education","marital-status","occupation","relationship","race","sex","native-country"];
drop_col=['native-country',"race"]
trained_dataset=readCSVFile(trainFile);
trained_data,trained_y=readTrainData(trained_dataset);

test_dataset=readCSVFile(testFile);
test_data,test_id=readTestData(test_dataset);

#droping unrelated-columns
dropColumns(trained_data,drop_col);
dropColumns(test_data,drop_col);

#impute:
imputeUnknowValue(trained_data);
imputeUnknowValue(test_data);

#converting categorical data to point wise data
byNumber=False;
dummy_trained_data=handleCategoryData(trained_data,categoryList,byNumber);
dummy_test_data=handleCategoryData(test_data,categoryList,byNumber);


#adding missing column
trained_columns_name=list(dummy_trained_data.columns.values);
addRemainingCol(trained_columns_name,dummy_test_data,len(trained_data))
test_columns_name=list(dummy_test_data.columns.values);

#converting panda data frame to numpy martix
mtx_dummy_tds=dummy_trained_data.as_matrix(columns=None)
mtx_dummy_testds=dummy_test_data.as_matrix(columns=None)
mtx_trained_y=trained_y.as_matrix(columns=None);
mtx_test_id=test_id.as_matrix(columns=None);

#adding bias column
mtx_dummy_tds=np.column_stack((mtx_dummy_tds,np.ones((len(mtx_dummy_tds),1))))
mtx_dummy_testds=np.column_stack((mtx_dummy_testds,np.ones((len(mtx_dummy_testds),1))))

#normalization
mtx_dummy_tds_norm=normalizePhi(mtx_dummy_tds)
mtx_dummy_testds_norm=normalizePhi(mtx_dummy_testds)


#print(mtx_dummy_tds)
#print(mtx_dummy_tds_norm)
#pandas.get_dummies(trained_data.ix[:,1:2])
print("train",np.shape(mtx_dummy_tds_norm),"test",np.shape(mtx_dummy_testds_norm))
# Out:
# Normalizing Phi...
# Normalization done.
# Normalizing Phi...
# Normalization done.
# train (38973, 60) test (6878, 60)

# %%
trained_dataset['native-country'] = trained_dataset['native-country'].astype('category') 
trained_dataset['native-country'].cat.categories
# Out:
# Index(['Cambodia', 'Canada', 'China', 'Columbia', 'Cuba', 'Dominican-Republic',
#        'Ecuador', 'El-Salvador', 'England', 'France', 'Germany', 'Greece',
#        'Guatemala', 'Haiti', 'Holand-Netherlands', 'Honduras', 'Hong',
#        'Hungary', 'India', 'Iran', 'Ireland', 'Italy', 'Jamaica', 'Japan',
#        'Laos', 'Mexico', 'Nicaragua', 'Outlying-US(Guam-USVI-etc)', 'Peru',
#        'Philippines', 'Poland', 'Portugal', 'Puerto-Rico', 'Scotland', 'South',
#        'Taiwan', 'Thailand', 'Trinadad&Tobago', 'United-States', 'Vietnam',
#        'Yugoslavia'],
#       dtype='object')

# %%
trained_dataset
# Out:
#           id  age         workclass  fnlwgt     education  education-num  \
# 0          0   25           Private  226802          11th              7
# 1          1   38           Private   89814       HS-grad              9
# 2          2   28         Local-gov  336951    Assoc-acdm             12
# 3          3   44           Private  160323  Some-college             10
# 4          5   34           Private  198693          10th              6
# 5          7   63  Self-emp-not-inc  104626   Prof-school             15
# 6          8   24           Private  369667  Some-college             10
# 7          9   55           Private  104996       7th-8th              4
# 8         10   65           Private  184454       HS-grad              9
# 9         12   26           Private   82091       HS-grad              9
# 10        13   58               NaN  299831       HS-grad              9
# 11        14   48           Private  279724       HS-grad              9
# 12        16   20         State-gov  444554  Some-college             10
# 13        17   43           Private  128354       HS-grad              9
# 14        18   37           Private   60548       HS-grad              9
# 15        19   40           Private   85019     Doctorate             16
# 16        20   34           Private  107914     Bachelors             13
# 17        23   25           Private  220931     Bachelors             13
# 18        24   25           Private  205947     Bachelors             13
# 19        25   45  Self-emp-not-inc  432824       HS-grad              9
# 20        26   22           Private  236427       HS-grad              9
# 21        27   23           Private  134446       HS-grad              9
# 22        28   54           Private   99516       HS-grad              9
# 23        29   32  Self-emp-not-inc  109282  Some-college             10
# 24        30   46         State-gov  106444  Some-college             10
# 25        31   56  Self-emp-not-inc  186651          11th              7
# 26        32   24  Self-emp-not-inc  188274     Bachelors             13
# 27        33   23         Local-gov  258120  Some-college             10
# 28        35   65               NaN  191846       HS-grad              9
# 29        36   36         Local-gov  403681     Bachelors             13
# ...      ...  ...               ...     ...           ...            ...
# 38943  48808   22           Private  203715  Some-college             10
# 38944  48809   31           Private  292592       HS-grad              9
# 38945  48810   29           Private  125976       HS-grad              9
# 38946  48811   35               NaN  320084     Bachelors             13
# 38947  48812   30               NaN   33811     Bachelors             13
# 38948  48813   34           Private  204461     Doctorate             16
# 38949  48814   54           Private  337992     Bachelors             13
# 38950  48815   37           Private  179137  Some-college             10
# 38951  48816   22           Private  325033          12th              8
# 38952  48817   34           Private  160216     Bachelors             13
# 38953  48818   30           Private  345898       HS-grad              9
# 38954  48819   38           Private  139180     Bachelors             13
# 38955  48820   71               NaN  287372     Doctorate             16
# 38956  48821   45         State-gov  252208       HS-grad              9
# 38957  48822   41               NaN  202822       HS-grad              9
# 38958  48823   72               NaN  129912       HS-grad              9
# 38959  48824   45         Local-gov  119199    Assoc-acdm             12
# 38960  48825   31           Private  199655       Masters             14
# 38961  48826   39         Local-gov  111499    Assoc-acdm             12
# 38962  48827   37           Private  198216    Assoc-acdm             12
# 38963  48828   43           Private  260761       HS-grad              9
# 38964  48829   65  Self-emp-not-inc   99359   Prof-school             15
# 38965  48830   43         State-gov  255835  Some-college             10
# 38966  48831   43  Self-emp-not-inc   27242  Some-college             10
# 38967  48832   32           Private   34066          10th              6
# 38968  48833   43           Private   84661     Assoc-voc             11
# 38969  48834   32           Private  116138       Masters             14
# 38970  48836   22           Private  310152  Some-college             10
# 38971  48839   58           Private  151910       HS-grad              9
# 38972  48840   22           Private  201490       HS-grad              9
#
#            marital-status         occupation    relationship  \
# 0           Never-married  Machine-op-inspct       Own-child
# 1      Married-civ-spouse    Farming-fishing         Husband
# 2      Married-civ-spouse    Protective-serv         Husband
# 3      Married-civ-spouse  Machine-op-inspct         Husband
# 4           Never-married      Other-service   Not-in-family
# 5      Married-civ-spouse     Prof-specialty         Husband
# 6           Never-married      Other-service       Unmarried
# 7      Married-civ-spouse       Craft-repair         Husband
# 8      Married-civ-spouse  Machine-op-inspct         Husband
# 9           Never-married       Adm-clerical   Not-in-family
# 10     Married-civ-spouse                NaN         Husband
# 11     Married-civ-spouse  Machine-op-inspct         Husband
# 12          Never-married      Other-service       Own-child
# 13     Married-civ-spouse       Adm-clerical            Wife
# 14                Widowed  Machine-op-inspct       Unmarried
# 15     Married-civ-spouse     Prof-specialty         Husband
# 16     Married-civ-spouse       Tech-support         Husband
# 17          Never-married     Prof-specialty   Not-in-family
# 18     Married-civ-spouse     Prof-specialty         Husband
# 19     Married-civ-spouse       Craft-repair         Husband
# 20          Never-married       Adm-clerical       Own-child
# 21              Separated  Machine-op-inspct       Unmarried
# 22     Married-civ-spouse       Craft-repair         Husband
# 23          Never-married     Prof-specialty   Not-in-family
# 24     Married-civ-spouse    Exec-managerial         Husband
# 25                Widowed      Other-service       Unmarried
# 26          Never-married              Sales   Not-in-family
# 27     Married-civ-spouse    Protective-serv         Husband
# 28     Married-civ-spouse                NaN         Husband
# 29     Married-civ-spouse     Prof-specialty         Husband
# ...                   ...                ...             ...
# 38943       Never-married       Adm-clerical       Own-child
# 38944  Married-civ-spouse  Machine-op-inspct            Wife
# 38945           Separated              Sales       Unmarried
# 38946  Married-civ-spouse                NaN            Wife
# 38947       Never-married                NaN   Not-in-family
# 38948  Married-civ-spouse     Prof-specialty         Husband
# 38949  Married-civ-spouse    Exec-managerial         Husband
# 38950            Divorced       Adm-clerical       Unmarried
# 38951       Never-married    Protective-serv       Own-child
# 38952       Never-married    Exec-managerial   Not-in-family
# 38953       Never-married       Craft-repair   Not-in-family
# 38954            Divorced     Prof-specialty       Unmarried
# 38955  Married-civ-spouse                NaN         Husband
# 38956           Separated       Adm-clerical       Own-child
# 38957           Separated                NaN   Not-in-family
# 38958  Married-civ-spouse                NaN         Husband
# 38959            Divorced     Prof-specialty       Unmarried
# 38960            Divorced      Other-service   Not-in-family
# 38961  Married-civ-spouse       Adm-clerical            Wife
# 38962            Divorced       Tech-support   Not-in-family
# 38963  Married-civ-spouse  Machine-op-inspct         Husband
# 38964       Never-married     Prof-specialty   Not-in-family
# 38965            Divorced       Adm-clerical  Other-relative
# 38966  Married-civ-spouse       Craft-repair         Husband
# 38967  Married-civ-spouse  Handlers-cleaners         Husband
# 38968  Married-civ-spouse              Sales         Husband
# 38969       Never-married       Tech-support   Not-in-family
# 38970       Never-married    Protective-serv   Not-in-family
# 38971             Widowed       Adm-clerical       Unmarried
# 38972       Never-married       Adm-clerical       Own-child
#
#                      race     sex  capital-gain  capital-loss  hours-per-week  \
# 0                   Black    Male             0             0              40
# 1                   White    Male             0             0              50
# 2                   White    Male             0             0              40
# 3                   Black    Male          7688             0              40
# 4                   White    Male             0             0              30
# 5                   White    Male          3103             0              32
# 6                   White  Female             0             0              40
# 7                   White    Male             0             0              10
# 8                   White    Male          6418             0              40
# 9                   White  Female             0             0              39
# 10                  White    Male             0             0              35
# 11                  White    Male          3103             0              48
# 12                  White    Male             0             0              25
# 13                  White  Female             0             0              30
# 14                  White  Female             0             0              20
# 15     Asian-Pac-Islander    Male             0             0              45
# 16                  White    Male             0             0              47
# 17                  White    Male             0             0              43
# 18                  White    Male             0             0              40
# 19                  White    Male          7298             0              90
# 20                  White    Male             0             0              20
# 21                  Black    Male             0             0              54
# 22                  White    Male             0             0              35
# 23                  White    Male             0             0              60
# 24                  Black    Male          7688             0              38
# 25                  White  Female             0             0              50
# 26                  White    Male             0             0              50
# 27                  White    Male             0             0              40
# 28                  White    Male             0             0              40
# 29                  White    Male             0             0              40
# ...                   ...     ...           ...           ...             ...
# 38943               White    Male             0             0              40
# 38944               White  Female             0             0              40
# 38945               White  Female             0             0              35
# 38946               White  Female             0             0              55
# 38947  Asian-Pac-Islander  Female             0             0              99
# 38948               White    Male             0             0              60
# 38949  Asian-Pac-Islander    Male             0             0              50
# 38950               White  Female             0             0              39
# 38951               Black    Male             0             0              35
# 38952               White  Female             0             0              55
# 38953               Black    Male             0             0              46
# 38954               Black  Female         15020             0              45
# 38955               White    Male             0             0              10
# 38956               White  Female             0             0              40
# 38957               Black  Female             0             0              32
# 38958               White    Male             0             0              25
# 38959               White  Female             0             0              48
# 38960               Other  Female             0             0              30
# 38961               White  Female             0             0              20
# 38962               White  Female             0             0              40
# 38963               White    Male             0             0              40
# 38964               White    Male          1086             0              60
# 38965               White  Female             0             0              40
# 38966               White    Male             0             0              50
# 38967  Amer-Indian-Eskimo    Male             0             0              40
# 38968               White    Male             0             0              45
# 38969  Asian-Pac-Islander    Male             0             0              11
# 38970               White    Male             0             0              40
# 38971               White  Female             0             0              40
# 38972               White    Male             0             0              20
#
#       native-country  salary
# 0      United-States       0
# 1      United-States       0
# 2      United-States       1
# 3      United-States       1
# 4      United-States       0
# 5      United-States       1
# 6      United-States       0
# 7      United-States       0
# 8      United-States       1
# 9      United-States       0
# 10     United-States       0
# 11     United-States       1
# 12     United-States       0
# 13     United-States       0
# 14     United-States       0
# 15               NaN       1
# 16     United-States       1
# 17              Peru       0
# 18     United-States       0
# 19     United-States       1
# 20     United-States       0
# 21     United-States       0
# 22     United-States       0
# 23     United-States       0
# 24     United-States       1
# 25     United-States       0
# 26     United-States       0
# 27     United-States       0
# 28     United-States       0
# 29     United-States       1
# ...              ...     ...
# 38943  United-States       0
# 38944  United-States       0
# 38945  United-States       0
# 38946  United-States       1
# 38947  United-States       0
# 38948  United-States       1
# 38949          Japan       1
# 38950  United-States       0
# 38951  United-States       0
# 38952  United-States       1
# 38953  United-States       0
# 38954  United-States       1
# 38955  United-States       1
# 38956  United-States       0
# 38957  United-States       0
# 38958  United-States       0
# 38959  United-States       0
# 38960  United-States       0
# 38961  United-States       1
# 38962  United-States       0
# 38963         Mexico       0
# 38964  United-States       0
# 38965  United-States       0
# 38966  United-States       0
# 38967  United-States       0
# 38968  United-States       0
# 38969         Taiwan       0
# 38970  United-States       0
# 38971  United-States       0
# 38972  United-States       0
#
# [38973 rows x 16 columns]

# %%
sb.countplot(y="workclass", hue='salary', data=trained_dataset)
#max frequent-data point is private, having salary greater than 1
# This feature is important in defining the output.

# %%
sb.countplot(y="occupation", hue='salary', data=trained_dataset)

# %%
sb.countplot(y="education", hue='salary', data=trained_dataset)

# %%
sb.countplot(y="education-num", hue='salary', data=trained_dataset)

# %%
plt.figure(figsize=(15,7), dpi=300)
sb.countplot(x="age", hue='salary', data=trained_dataset)

# %%
sb.factorplot(x="education-num", y="age", hue="salary", data=trained_dataset)
#numerica col

# %%
sb.factorplot(x="education-num", y="fnlwgt", hue="salary", data=trained_dataset)

# %%
sb.factorplot(x="education-num", y="age", hue="salary", col="occupation", size=20,col_wrap=1, data=trained_dataset)

# %%
sb.factorplot("salary", col="race",kind="count", col_wrap=3, data=trained_dataset)

#g = sns.factorplot("alive", col="deck", col_wrap=4,data=titanic[titanic.deck.notnull()],="count", size=2.5, aspect=.8)

# %%
plt.figure(figsize=(7,10), dpi=300)
p=sb.countplot(y="native-country", hue='salary',data=trained_dataset)
#p.set_xticklabels("native-country",rotation=30)
#for item in p.get_xticklabels():
#item.set_rotation(45)

# %%
p=sb.countplot(y="sex", hue='salary',data=trained_dataset)

# %%
col="education-num";
trained_dataset[col].groupby([trained_dataset[col],trained_dataset["age"],trained_dataset['salary']]).count()
# Out:
# education-num  age  salary
# 1              19   0          2
#                20   0          1
#                21   0          5
#                23   0          2
#                24   0          2
#                25   0          1
#                26   0          1
#                27   0          1
#                28   0          1
#                30   0          2
#                31   0          2
#                32   0          2
#                33   0          2
#                34   0          1
#                35   0          1
#                36   0          2
#                37   0          2
#                39   0          2
#                40   0          3
#                42   0          2
#                43   0          1
#                46   0          1
#                47   0          1
#                48   0          1
#                49   0          1
#                50   0          2
#                51   0          2
#                52   0          2
#                53   0          1
#                54   0          3
#                               ..
# 16             60   1          3
#                61   0          2
#                     1          6
#                62   0          1
#                     1          8
#                63   0          1
#                     1          1
#                64   1         11
#                65   1          1
#                66   0          1
#                     1          2
#                67   0          2
#                     1          6
#                68   0          3
#                     1          4
#                69   1          3
#                70   1          2
#                71   1          1
#                72   0          2
#                     1          2
#                73   0          1
#                     1          1
#                74   1          2
#                75   0          1
#                     1          1
#                77   0          1
#                     1          2
#                79   0          1
#                     1          2
#                80   0          1
# Name: education-num, dtype: int64

# %%
col="education-num";
trained_dataset[col].groupby([trained_dataset[col], trained_dataset['salary']]).count()
# Out:
# education-num  salary
# 1              0            64
#                1             1
# 2              0           188
#                1             6
# 3              0           389
#                1            19
# 4              0           708
#                1            43
# 5              0           580
#                1            29
# 6              0          1073
#                1            75
# 7              0          1374
#                1            74
# 8              0           484
#                1            38
# 9              0         10543
#                1          2021
# 10             0          6997
#                1          1634
# 11             0          1232
#                1           414
# 12             0           935
#                1           322
# 13             0          3793
#                1          2627
# 14             0           958
#                1          1193
# 15             0           170
#                1           502
# 16             0           137
#                1           350
# Name: education-num, dtype: int64

# %%
print("aa");
# Out:
# aa
